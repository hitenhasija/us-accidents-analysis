# %% [markdown]
# # EDA FOR US ACCIDENTS(2016 - 2023)

# %% [markdown]
# ### Dataset Description
#
# This is a countrywide car accident dataset that covers 49 states of the USA. The accident data were collected from February 2016 to March 2023, using multiple APIs that provide streaming traffic incident (or event) data. These APIs broadcast traffic data captured by various entities, including the US and state departments of transportation, law enforcement agencies, traffic cameras, and traffic sensors within the road networks. The dataset currently contains approximately 7.7 million accident records. For more information about this dataset, please visit [here](#).
#
# #### Columns:
#
# - **ID**: This is a unique identifier of the accident record.
# - **Source**: Source of raw accident data.
# - **Severity**: Shows the severity of the accident, a number between 1 and 4, where 1 indicates the least impact on traffic (i.e., short delay as a result of the accident) and 4 indicates a significant impact on traffic (i.e., long delay).
# - **Start_Time**: Shows start time of the accident in local time zone.
# - **End_Time**: Shows end time of the accident in local time zone. End time here refers to when the impact of accident on traffic flow was dismissed.
# - **Start_Lat**: Shows latitude in GPS coordinate of the start point.
# - **Start_Lng**: Shows longitude in GPS coordinate of the start point.
# - **End_Lat**: Shows latitude in GPS coordinate of the end point.
# - **End_Lng**: Shows longitude in GPS coordinate of the end point.
# - **Distance(mi)**: The length of the road extent affected by the accident in miles.
# - **Description**: Shows a human provided description of the accident.
# - **Street**: Shows the street name in address field.
# - **City**: Shows the city in address field.
# - **County**: Shows the county in address field.
# - **State**: Shows the state in address field.
# - **Zipcode**: Shows the zipcode in address field.
# - **Country**: Shows the country in address field.
# - **Timezone**: Shows timezone based on the location of the accident (eastern, central, etc.).
# - **Airport_Code**: Denotes an airport-based weather station which is the closest one to location of the accident.
# - **Weather_Timestamp**: Shows the time-stamp of weather observation record (in local time).
# - **Temperature(F)**: Shows the temperature (in Fahrenheit).
# - **Wind_Chill(F)**: Shows the wind chill (in Fahrenheit).
# - **Humidity(%)**: Shows the humidity (in percentage).
# - **Pressure(in)**: Shows the air pressure (in inches).
# - **Visibility(mi)**: Shows visibility (in miles).
# - **Wind_Direction**: Shows wind direction.
# - **Wind_Speed(mph)**: Shows wind speed (in miles per hour).
# - **Precipitation(in)**: Shows precipitation amount in inches, if there is any.
# - **Weather_Condition**: Shows the weather condition (rain, snow, thunderstorm, fog, etc.).
# - **Amenity**: A POI annotation which indicates presence of amenity in a nearby location.
# - **Bump**: A POI annotation which indicates presence of speed bump or hump in a nearby location.
# - **Crossing**: A POI annotation which indicates presence of crossing in a nearby location.
# - **Give_Way**: A POI annotation which indicates presence of give_way in a nearby location.
# - **Junction**: A POI annotation which indicates presence of junction in a nearby location.
# - **No_Exit**: A POI annotation which indicates presence of no_exit in a nearby location.
# - **Railway**: A POI annotation which indicates presence of railway in a nearby location.
# - **Roundabout**: A POI annotation which indicates presence of roundabout in a nearby location.
# - **Station**: A POI annotation which indicates presence of station in a nearby location.
# - **Stop**: A POI annotation which indicates presence of stop in a nearby location.
# - **Traffic_Calming**: A POI annotation which indicates presence of traffic_calming in a nearby location.
# - **Traffic_Signal**: A POI annotation which indicates presence of traffic_signal in a nearby location.
# - **Turning_Loop**: A POI annotation which indicates presence of turning_loop in a nearby location.
# - **Sunrise_Sunset**: Shows the period of day (i.e. day or night) based on sunrise/sunset.
# - **Civil_Twilight**: Shows the period of day (i.e. day or night) based on civil twilight.
# - **Nautical_Twilight**: Shows the period of day (i.e. day or night) based on nautical twilight.
# - **Astronomical_Twilight**: Shows the period of day (i.e. day or night) based on astronomical twilight.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# #### **Load the Dataset**

# %%
df = pd.read_csv('US_Accidents_March23.csv')

# %% [markdown]
# #### **Data Processing and Cleaning**
#
# 1. Basic understanding of Dataset
# 2. Taking care of Null Values and Duplicated Values

# %%
# Display the first 5 rows of the dataframe to get an initial understanding of the data
df.sample(5)
# Out:
#                 ID   Source  Severity          Start_Time            End_Time  \
# 3446986  A-3456869  Source1         2 2017-01-06 11:29:44 2017-01-06 17:56:04
# 4941589  A-4979040  Source1         2 2022-07-24 02:26:43 2022-07-24 03:41:43
# 2222885  A-2232752  Source2         2 2019-03-22 11:20:14 2019-03-22 12:35:40
# 4988892  A-5026697  Source1         2 2022-11-07 08:49:05 2022-11-07 10:05:36
# 6827118  A-6876290  Source1         2 2020-11-14 05:27:01 2020-11-14 11:15:00
#
#          Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  ...  \
# 3446986  41.174410 -79.697530  41.174110 -79.734650         1.931  ...
# 4941589  29.856258 -95.376265  29.856316 -95.371944         0.259  ...
# 2222885  42.480122 -70.947594        NaN        NaN         0.000  ...
# 4988892  33.801987 -92.376292  33.800017 -92.372719         0.246  ...
# 6827118  32.678911 -96.674985  32.681779 -96.661686         0.798  ...
#
#         Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
# Display the shape of the dataframe to understand the number of rows and columns
df.shape
# Out:
# (7728394, 46)

# %%
# Display the summary information of the dataframe, including the number of non-null entries, data types, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
# Changing Start_Time and End_time from object to datetime

df['Start_Time'] = pd.to_datetime(df['Start_Time'], format='mixed')
df['End_Time'] = pd.to_datetime(df['End_Time'], format='mixed')

# %%
# Display the summary information of the dataframe, including the number of non-null entries, data types, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             datetime64[ns]
#  4   End_Time               datetime64[ns]
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
# This cell calculates the number of unique values in each column of the dataframe `df`
# and sorts the result in ascending order.
df.nunique().sort_values(ascending=False)
# Out:
# ID                       7728394
# End_Time                 6463024
# Start_Time               5801064
# Description              3761578
# Start_Lng                2482533
# Start_Lat                2428358
# End_Lng                  1605789
# End_Lat                  1568172
# Weather_Timestamp         941331
# Zipcode                   825094
# Street                    336306
# Distance(mi)               22382
# City                       13678
# Airport_Code                2045
# County                      1871
# Pressure(in)                1144
# Wind_Chill(F)               1001
# Temperature(F)               860
# Precipitation(in)            299
# Wind_Speed(mph)              184
# Weather_Condition            144
# Humidity(%)                  100
# Visibility(mi)                92
# State                         49
# Wind_Direction                24
# Hour                          24
# Month                         12
# Year                           8
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
# This cell calculates the number of missing values in each column of the dataframe `df`
# and sorts the result in descending order. It then calculates the percentage of missing values
# for each column that has missing values and stores it in `non_zero_null_perc_colums`.
non_zero_null_col = df.isnull().sum().sort_values(ascending=False)
non_zero_null_perc_colums= non_zero_null_col[non_zero_null_col!=0]*100/df.shape[0]
non_zero_null_perc_colums
# Out:
# End_Lng                  44.029355
# End_Lat                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Sunrise_Sunset            0.300787
# Civil_Twilight            0.300787
# Astronomical_Twilight     0.300787
# Nautical_Twilight         0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# dtype: float64

# %%
#plotting graph for only columns having missing values
# Calculate the percentage of missing values for each column
missing_percentage = non_zero_null_perc_colums

# Plot the bar plot with percentages beside the bars
fig = plt.figure(figsize=(12, 10))
sns.barplot(x=missing_percentage, y=missing_percentage.index, palette='plasma', hue=missing_percentage.index, dodge=False, legend=False)
for container in plt.gca().containers:
    plt.gca().bar_label(container, fmt='%.3f%%')
plt.xlabel('Percentage of missing values')
plt.ylabel('Columns')
plt.title('Percentage of missing values in each column')
plt.show()

# %%
# Checking for Duplicated Rows in the dataset

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > No Duplicate rows in the Dataset

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# > ### **Insights from Correlation Heatmap**
# >
# > 1. **Temperature and Wind Chill**:
# >    - Strong positive correlation (0.8+) between Temperature and Wind Chill
# >    - Expected as wind chill typically follows temperature trends
# >
# > 2. **Visibility and Atmospheric Conditions**:
# >    - Moderate negative correlation (-0.3) between Humidity and Visibility
# >    - Higher humidity tends to reduce visibility
# >    - Weak positive correlation between Pressure and Visibility
# >
# > 3. **Weather Parameters**:
# >    - Weak negative correlation between Temperature and Humidity
# >    - Weak negative correlation between Wind Speed and Pressure
# >    - Minimal correlation between Precipitation and other variables
# >
# > 4. **Accident Severity**:
# >    - Very weak correlations between Severity and weather parameters
# >    - Suggests severity may be more influenced by non-weather factors
# >
# > 5. **Distance**:
# >    - Distance shows minimal correlation with all other variables
# >    - Indicates accident impact length is independent of weather conditions

# %% [markdown]
# # **EDA and Visualization**

# %%
# This cell provides descriptive statistics for the dataframe `df`.
# It includes measures such as count, mean, standard deviation, min, max, and percentiles for numeric columns.
df.describe()
# Out:
#            Severity                     Start_Time  \
# count  7.728394e+06                        7728394
# mean   2.212384e+00  2020-06-04 04:23:22.765653760
# min    1.000000e+00            2016-01-14 20:18:33
# 25%    2.000000e+00  2018-11-23 04:01:12.249999872
# 50%    2.000000e+00            2020-11-11 08:40:22
# 75%    2.000000e+00     2022-01-20 07:30:08.500000
# max    4.000000e+00            2023-03-31 23:30:00
# std    4.875313e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        7728394  7.728394e+06  7.728394e+06
# mean   2020-06-04 11:47:48.023095040  3.620119e+01 -9.470255e+01
# min              2016-02-08 06:37:08  2.455480e+01 -1.246238e+02
# 25%       2018-11-23 05:45:20.500000  3.339963e+01 -1.172194e+02
# 50%              2020-11-11 15:56:29  3.582397e+01 -8.776662e+01
# 75%              2022-01-20 17:44:40  4.008496e+01 -8.035368e+01
# ...

# %% [markdown]
# > ### Insights:
# >
# > - On average, accidents happen even when the visibility is around 9 miles, indicating that visibility is not a major contributing factor.
# > - In approximately 75% of cases, no precipitation was recorded, suggesting that rain is not a significant cause of accidents.
# > - The average length of the road extent affected by the accident is 0.5 miles, indicating that most accidents impact a relatively short stretch of road.

# %% [markdown]
# ### City and States analysis

# %% [markdown]
# How many total Cities are there

# %%
df['City'].nunique()
# Out:
# 13678

# %% [markdown]
# > There are total 13678 Cities in the dataset

# %% [markdown]
# How many States are there

# %%
df['State'].nunique()
# Out:
# 49

# %% [markdown]
# > There are total 49 states in the dataset which implies 1 state out of 50 is not included in the dataset

# %%
fig = plt.figure(figsize = (11,4))
fig.suptitle('Top 20 States by Percentage of Accidents')
# Get the top 20 states by count
top_states = df['State'].value_counts()[:20]*100/df.shape[0]


# Create a bar plot

perc_states = sns.barplot(x=top_states.index, y=top_states.values, palette='viridis', hue=top_states.index)
# Add percentage labels on the bars

for i in perc_states.containers:
    perc_states.bar_label(i, fmt='%.2f%%', label_type='edge')
# Rotate x-axis labels for better readability
plt.xticks(rotation=90)
plt.ylabel('Percentage of Accidents')

plt.show()

# %% [markdown]
# >### Insights on Top States by Percentage of Accidents
# >
# >1. **California Dominance**:
# >    - California accounts for ~22.5% of all US accidents
# >    - This represents more than 1 in 5 accidents nationwide
# >    - Likely due to large population and extensive road network
# >
# >2. **Florida and Texas**:
# >    - Florida has ~11.4% of accidents
# >    - Texas follows with ~7.5% of accidents
# >    - Both states have high populations and significant tourism
# >
# >3. **East Coast Concentration**:
# >    - Strong representation from eastern states (SC, NY, NC, VA, PA)
# >    - Combined these states account for over 20% of accidents
# >    - High population density likely a contributing factor
# >
# >4. **Regional Distribution**:
# >    - Top 10 states represent all major US regions
# >    - Northeast: NY, PA
# >    - Southeast: FL, SC, NC, VA
# >    - West: CA, OR
# >    - Midwest: MN
# >
# >5. **Population Correlation**:
# >    - Most top states have large populations
# >    - Exception: SC ranks 4th in accidents (~5%) despite smaller population
# >    - Suggests factors beyond population affect accident rates

# %%
fig = plt.figure(figsize = (11,4))
fig.suptitle('Top 20 Cities by Percentage of Accidents')
# Get the top 20 Cities by count
top_cities = df['City'].value_counts()[:20]*100/df.shape[0]

# Create a bar plot
perc_cities = sns.barplot(x=top_cities.index, y=top_cities.values, palette='viridis', hue=top_cities.index, legend=False)
for i in perc_cities.containers:
    perc_cities.bar_label(i, fmt='%.2f%%', label_type='edge')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)
plt.ylabel('Percentage of Accidents')

plt.show()

# %% [markdown]
# > ### Insights on Top Cities by Percentage of Accidents
# > 1. **Miami (2.42%)**:
# >    - Ranks highest in percentage of accidents
# >    - Nearly 1 in 40 US accidents occur in Miami
# >    - Tropical weather conditions and high tourism may contribute
# >
# > 2. **Houston (2.19%)** and **Los Angeles (2.02%)**:
# >    - Second and third highest percentages
# >    - Both are major metropolitan areas with heavy traffic volumes
# >    - Together account for over 4% of all US accidents
# >
# > 3. **Charlotte (1.79%)** and **Dallas (1.69%)**:
# >    - Represent growing southern metropolitan areas
# >    - High percentage likely due to rapid population growth
# >    - Combined make up about 3.5% of total accidents
# >
# > 4. **Urban Concentration**:
# >    - Top 10 cities account for over 15% of all accidents
# >    - All are major metropolitan areas with high population density
# >    - Suggests correlation between urban density and accident frequency
# >
# > 5. **Regional Distribution**:
# >    - Strong representation from southern cities (Miami, Houston, Dallas, Orlando)
# >    - Coastal cities feature prominently (Miami, Los Angeles, San Diego)
# >    - Mix of fast-growing and established metropolitan areas

# %%
timezone_max_acc=df['Timezone'].value_counts()
plt.figure(figsize=(12,5))
sns.barplot(y=timezone_max_acc.index, x=timezone_max_acc, hue=timezone_max_acc.index)
plt.title("Accident cases for different timezones in US",size=17)
plt.xlabel('Timezone')
plt.ylabel('No. of accidents')
# Out:
# Text(0, 0.5, 'No. of accidents')

# %% [markdown]
# > ### Insights on Number of Accidents in Different Timezones in the US
# >
# >1. **US/Eastern Timezone**:
# >    - The US/Eastern timezone has the highest number of accidents, accounting for approximately 46.3% of the total accidents.
# >    - This high percentage can be attributed to the dense population and heavy traffic in major cities like New York, Miami, and Atlanta.
# >
# >2. **US/Pacific Timezone**:
# >    - The US/Pacific timezone follows with around 26.7% of the total accidents.
# >    - Major cities like Los Angeles, San Francisco, and Seattle contribute significantly to this count.
# >
# >3. **US/Central Timezone**:
# >    - The US/Central timezone accounts for about 21.3% of the total accidents.
# >    - Cities like Houston, Dallas, and Chicago are major contributors to the accident count in this timezone.
# >
# >4. **US/Mountain Timezone**:
# >    - The US/Mountain timezone has the lowest number of accidents, making up approximately 5.6% of the total accidents.
# >    - This lower percentage can be attributed to the relatively lower population density and traffic volume in this region.
# >
# >5. **General Observations**:
# >    - The distribution of accidents across different timezones highlights the impact of population density and traffic volume on accident occurrences.
# >    - Timezones with major metropolitan areas tend to have higher accident counts, emphasizing the need for targeted road safety measures in these regions.

# %%
street_acc_count=df['Street'].value_counts()
street_max_acc=street_acc_count.head(10)
plt.figure(figsize=(12,5))
sns.barplot(y=street_max_acc.index, x=street_max_acc , hue=street_max_acc.index)
plt.title("Top 10 Accident Prone Streets in US ",size=17,color="grey")
plt.xlabel('Streets')
plt.ylabel('No. of accidents')
plt.show()

# %% [markdown]
# >### Insights on Top 10 Accident Prone Streets in the US
# >
# >1. **I-95 N**:
# >    - I-95 N has the highest number of accidents, making it the most accident-prone street in the dataset.
# >    - This interstate runs along the East Coast, connecting major cities and contributing to high traffic volumes.
# >
# >2. **I-95 S**:
# >    - I-95 S follows closely behind I-95 N in terms of accident count.
# >    - The southbound direction of this major interstate also experiences significant traffic, leading to a high number of accidents.
# >
# >3. **I-5 N**:
# >    - I-5 N is another major interstate with a high accident count.
# >    - This interstate runs along the West Coast, connecting key cities and contributing to heavy traffic.
# >
# >4. **I-10 E**:
# >    - I-10 E ranks fourth in terms of accident count.
# >    - This eastbound interstate runs across the southern part of the country, connecting major cities and contributing to high traffic volumes.
# >
# >5. **I-10 W**:
# >    - I-10 W follows closely behind I-10 E in terms of accident count.
# >    - The westbound direction of this major interstate also experiences significant traffic, leading to a high number of accidents.
# >
# >6. **I-5 S**:
# >    - I-5 S is another major interstate with a high accident count.
# >    - The southbound direction of this interstate runs along the West Coast, contributing to heavy traffic and accidents.
# >
# >7. **I-80 W**:
# >    - I-80 W ranks seventh in terms of accident count.
# >    - This westbound interstate runs across the northern part of the country, connecting major cities and contributing to high traffic volumes.
# >
# >8. **I-80 E**:
# >    - I-80 E follows closely behind I-80 W in terms of accident count.
# >    - The eastbound direction of this major interstate also experiences significant traffic, leading to a high number of accidents.
# >
# >9. **I-405 N**:
# >    - I-405 N is another major interstate with a high accident count.
# >    - This northbound interstate runs through densely populated areas, contributing to heavy traffic and accidents.
# >
# >10. **I-75 N**:
# >    - I-75 N ranks tenth in terms of accident count.
# >    - This northbound interstate runs through the central part of the country, connecting major cities and contributing to high traffic volumes.
# >
# >### General Observations:
# >    - The top 10 accident-prone streets are all major interstates, highlighting the impact of high traffic volumes on accident occurrences.
# >    - Both northbound and southbound/eastbound and westbound directions of these interstates are represented, indicating that traffic flow in both directions contributes to accidents.
# >    - These interstates connect major cities and run through densely populated areas, leading to increased traffic and a higher likelihood of accidents.

# %% [markdown]
# #### **Questions about Data**
#
# - Whether presence of a speed bump affects the severity of the accident or not (Answered)
# - Are accidents taking more time more severe
# - Does accidents having more distance considered more severe
# - Does having traffic_calming measures affect number of accidents (Answered)
# - Does having traffic_signals affect number of accidents (Answered)
# - In a low visibility environment, how much percentage of accidents are there where there is a pedestrian crossing(crossing) nearby
# - Top 10 States with most accidents (Answered)
# - Top 10 Cities with most accidents (Answered)
# - Geo-Map indicating number of accidents in different states using a colormap
# - Accident count based on Day/Night Conditions (Answered)
# - Accident count in different weather conditions (Answered)
# - Interactive map where we select a state and it shows the Accident count in the state's cities using a colormap
# - Accidents based on whether there was a stop sign nearby or not
# - Does temperature of the environment affect the number of accidents and its severity (Answered)
# - Do weather conditions affect the severity of the accident (Answered)
# - We subtract the End_time of the accident to the Start_time to obtain the timespan of the accident and when we divide by the distance it covered in its impact, we can obtain the speed of impact of the accident which can be compared with the severity of the accident which in total may give more information about the accident itself
# - how many accidents happen in each month from 2016-2023 (Answered)

# %% [markdown]
# ### Severity Analysis

# %%
accidents_severity = df.groupby('Severity').count()['ID']
accidents_severity

fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))
label = [1,2,3,4]
plt.pie(accidents_severity, labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
circle = plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
ax.set_title("Accident by Severity",fontdict={'fontsize': 16})
plt.tight_layout()
plt.show()

# %% [markdown]
# >### Insights on Percentage of Accidents by Severity
# >
# >1. **Severity 2 Accidents**:
# >    - The majority of accidents fall under Severity 2, accounting for approximately 80% of the total accidents.
# >    - This indicates that most accidents have a moderate impact on traffic and safety.
# >
# >2. **Severity 3 Accidents**:
# >    - Severity 3 accidents make up around 16% of the total accidents.
# >    - These accidents have a more significant impact compared to Severity 2, but are less common.
# >
# >3. **Severity 1 Accidents**:
# >    - Severity 1 accidents account for about 3% of the total accidents.
# >    - These accidents have the least impact on traffic and safety.
# >
# >4. **Severity 4 Accidents**:
# >    - Severity 4 accidents are the least common, making up only about 1% of the total accidents.
# >    - These accidents have the most severe impact on traffic and safety.
# >
# >5. **General Observations**:
# >    - The distribution of accidents by severity shows that the majority of accidents are of moderate severity (Severity 2).
# >    - There is a significant drop in the percentage of accidents as the severity level increases, indicating that more severe accidents are less frequent.
# >    - Understanding the distribution of accidents by severity can help in prioritizing road safety measures and interventions.

# %%
fig.suptitle('Top 10 States by Severity of Accidents', fontsize=16)
s4_state_count = df[df['Severity']==4]['State'].value_counts()[:10]
s3_state_count = df[df['Severity']==3]['State'].value_counts()[:10]
s2_state_count = df[df['Severity']==2]['State'].value_counts()[:10]
s1_state_count = df[df['Severity']==1]['State'].value_counts()[:10]

fig, axes = plt.subplots(4,1, figsize = (12, 20))
axes[0].bar(s1_state_count.index, s1_state_count.values, color='red')
axes[1].bar(s2_state_count.index, s2_state_count.values, color='red')
axes[2].bar(s3_state_count.index, s3_state_count.values, color='red')
axes[3].bar(s4_state_count.index, s4_state_count.values, color='red')
axes[0].set_title('Severity 1')
axes[1].set_title('Severity 2')
axes[2].set_title('Severity 3')
axes[3].set_title('Severity 4')
axes[0].set_ylabel('Count')
axes[1].set_ylabel('Count')
axes[2].set_ylabel('Count')
axes[3].set_ylabel('Count')
axes[0].set_xlabel('State')
axes[1].set_xlabel('State')
axes[2].set_xlabel('State')
axes[3].set_xlabel('State')
plt.tight_layout()
for ax, state_count in zip(axes, [s1_state_count, s2_state_count, s3_state_count, s4_state_count]):
    for container in ax.containers:
        ax.bar_label(container)
plt.show()

# %% [markdown]
# >### Insights on Top 10 States by Severity of Accidents
# >
# >1. **Severity 1 Accidents**:
# >    - California (CA) has the highest count of Severity 1 accidents, followed by Arizona (AZ) and Florida (FL).
# >    - The distribution of Severity 1 accidents is relatively even among the top states, with each state contributing a significant portion.
# >
# >2. **Severity 2 Accidents**:
# >    - California (CA) leads with a substantial margin in Severity 2 accidents, followed by Florida (FL) and Texas (TX).
# >    - The top 3 states (CA, FL, TX) together account for a large proportion of Severity 2 accidents, indicating higher traffic volumes and accident occurrences in these states.
# >
# >3. **Severity 3 Accidents**:
# >    - California (CA) again has the highest count of Severity 3 accidents, followed by Texas (TX) and Florida (FL).
# >    - The distribution shows that Severity 3 accidents are more concentrated in a few states, with CA, TX, and FL having significantly higher counts compared to others.
# >
# >4. **Severity 4 Accidents**:
# >    - Virginia (VA) has the highest count of Severity 4 accidents, followed by Pennsylvania (PA) and California (CA).
# >    - The presence of Severity 4 accidents in states like VA and PA indicates that these states experience more severe accidents, possibly due to specific road conditions or traffic patterns.
# >
# >5. **General Observations**:
# >    - California (CA) consistently appears as the state with the highest number of accidents across all severity levels, highlighting the need for targeted road safety measures.
# >    - The distribution of accidents by severity shows that certain states have higher occurrences of severe accidents, which may require focused interventions to improve road safety.
# >    - The variation in accident counts across different severity levels suggests that factors contributing to accident severity may differ by state, necessitating state-specific analysis and solutions.

# %%
s4_city_count = df[df['Severity']==4]['City'].value_counts()[:10]
s3_city_count = df[df['Severity']==3]['City'].value_counts()[:10]
s2_city_count = df[df['Severity']==2]['City'].value_counts()[:10]
s1_city_count = df[df['Severity']==1]['City'].value_counts()[:10]

fig, axes = plt.subplots(4,1, figsize = (12, 20))
axes[0].bar(s1_city_count.index, s1_city_count.values, color='red')
axes[1].bar(s2_city_count.index, s2_city_count.values, color='red')
axes[2].bar(s3_city_count.index, s3_city_count.values, color='red')
axes[3].bar(s4_city_count.index, s4_city_count.values, color='red')
axes[0].set_title('Severity 1')
axes[1].set_title('Severity 2')
axes[2].set_title('Severity 3')
axes[3].set_title('Severity 4')
axes[0].set_ylabel('Count')
axes[1].set_ylabel('Count')
axes[2].set_ylabel('Count')
axes[3].set_ylabel('Count')
axes[0].set_xlabel('City')
axes[1].set_xlabel('City')
axes[2].set_xlabel('City')
axes[3].set_xlabel('City')
plt.tight_layout()
for ax, city_count in zip(axes, [s1_city_count, s2_city_count, s3_city_count, s4_city_count]):
    for container in ax.containers:
        ax.bar_label(container)
plt.show()

# %% [markdown]
# >### Insights on Top 10 Cities by Severity of Accidents
#
# >1. **Severity 1 Accidents**:
# >    - Tucson has the highest count of Severity 1 accidents, followed by Charlotte and Phoenix.
# >    - The distribution of Severity 1 accidents is relatively even among the top cities, with each city contributing a significant portion.
# >
# >2. **Severity 2 Accidents**:
# >    - Miami leads with a substantial margin in Severity 2 accidents, followed by Houston and Charlotte.
# >    - The top 3 cities (Miami, Houston, Charlotte) together account for a large proportion of Severity 2 accidents, indicating higher traffic volumes and accident occurrences in these cities.
# >
# >3. **Severity 3 Accidents**:
# >    - Los Angeles has the highest count of Severity 3 accidents, followed by Dallas and Atlanta.
# >    - The distribution shows that Severity 3 accidents are more concentrated in a few cities, with Los Angeles, Dallas, and Atlanta having significantly higher counts compared to others.
# >
# >4. **Severity 4 Accidents**:
# >    - Atlanta has the highest count of Severity 4 accidents, followed by Miami and Visalia.
# >    - The presence of Severity 4 accidents in cities like Atlanta and Miami indicates that these cities experience more severe accidents, possibly due to specific road conditions or traffic patterns.
# >
# >5. **General Observations**:
# >    - Miami consistently appears as the city with the highest number of accidents across all severity levels, highlighting the need for targeted road safety measures.
# >    - The distribution of accidents by severity shows that certain cities have higher occurrences of severe accidents, which may require focused interventions to improve road safety.
# >    - The variation in accident counts across different severity levels suggests that factors contributing to accident severity may differ by city, necessitating city-specific analysis and solutions.

# %%
df.groupby(['Traffic_Signal', 'Severity']).size().reset_index(name='counts')
# Out:
#    Traffic_Signal  Severity   counts
# 0           False         1    41025
# 1           False         2  5148309
# 2           False         3  1210728
# 3           False         4   184560
# 4            True         1    26341
# 5            True         2  1008672
# 6            True         3    88609
# 7            True         4    20150

# %% [markdown]
# ### Date-Time Analysis

# %%
# Extract month and year from Start_Time
df['Month'] = df['Start_Time'].dt.month
df['Year'] = df['Start_Time'].dt.year

# Group by year and month and count occurrences
monthly_accidents = df.groupby(['Year', 'Month']).size().unstack(fill_value=0)
monthly_accidents = monthly_accidents.loc[2016:2022]

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(monthly_accidents, cmap='YlGnBu', annot=True, fmt='d')
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Number of Accidents by Month and Year')
plt.show()

# %% [markdown]
# > ### Insights on Number of Accidents by Month and Year
# >
# > 1. **Increasing Trend Over the Years**:
# >    - The heatmap shows a clear increasing trend in the number of accidents from 2016 to 2022.
# >    - This indicates a growing number of accidents over the years, which may be due to various factors such as increased traffic volume, changes in reporting practices, or other external factors.
# >
# > 2. **Seasonal Variations**:
# >    - There are noticeable seasonal variations in the number of accidents.
# >    - The winter months (November, December, January) consistently show higher numbers of accidents across all years.
# >    - This trend suggests that adverse weather conditions during winter, such as snow, ice, and reduced visibility, contribute to an increase in accident occurrences.
# >
# > 3. **Summer Peaks**:
# >    - The summer months (June, July, August) also show higher numbers of accidents in certain years.
# >    - Increased travel during summer vacations and holidays may contribute to this trend.
# >
# > 4. **Impact of COVID-19 Pandemic**:
# >    - There is a noticeable spike in the number of accidents in 2020, particularly in the later months of the year.
# >    - This spike could be attributed to changes in traffic patterns and behaviors due to the COVID-19 pandemic, such as increased local travel and changes in commuting habits.
# >
# > 5. **Monthly Trends**:
# >    - The number of accidents tends to be higher at the beginning and end of the year.
# >    - There is a noticeable dip in the number of accidents during the spring months (March, April, May).
# >
# > 6. **Yearly Peaks**:
# >    - The year 2022 recorded the highest number of accidents, particularly in the winter months.
# >    - This trend suggests an overall increase in accident occurrences, highlighting the need for enhanced road safety measures.
# >
# > 7. **General Observations**:
# >    - Understanding the distribution of accidents by month and year can help in identifying patterns and trends.
# >    - This information can be used to develop targeted road safety measures and interventions to reduce accident occurrences and improve overall traffic safety.

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x = df['Start_Time'].dt.year.value_counts().sort_index().index[:-1], 
             y = df['Start_Time'].dt.year.value_counts().sort_index().values[:-1], 
            color='red')

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.title('Number of Accidents per Year')
plt.show()

# %% [markdown]
# > ### Insights on Number of Accidents per Year
# >
# > - The number of accidents has generally increased over the years.
# > - There's a noticeable jump in the number of accidents around 2020.
# > - The trend peaks in the later years of the dataset, specifically in 2022.

# %%
df_filtered = df[df['Start_Time'].dt.year!=2023].copy()
df_year_severity = df_filtered.groupby([df_filtered['Start_Time'].dt.year, 'Severity']).size().reset_index(name='Count')

# Plot the data
plt.figure(figsize=(12,5))
sns.lineplot(data=df_year_severity, x='Start_Time', y='Count', hue='Severity', palette='viridis')
plt.title('Distribution of Accidents by Year and Severity')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# > ### Insights from Year and Severity Plot
# >
# > 1. **Steady Increase in Severity 2 Accidents**:
# >    - There is a noticeable and steady increase in the number of Severity 2 accidents from 2016 to 2022.
# >    - This indicates that the majority of accidents fall under the moderate severity category and have been increasing over the years.
# >
# > 2. **Fluctuations in Severity 3 Accidents**:
# >    - Severity 3 accidents peaked in 2018 and then showed a significant decrease in the following years.
# >    - This fluctuation suggests that while there was a period of higher severity accidents, measures might have been taken to reduce their occurrence.
# >
# > 3. **Stable Numbers for Severity 1 and 4 Accidents**:
# >    - The number of Severity 1 (least severe) and Severity 4 (most severe) accidents have remained relatively stable over the years.
# >    - This stability indicates that the least and most severe accidents have not seen significant changes in their occurrence rates.
# >
# > 4. **Spike in 2020**:
# >    - There is a noticeable spike in the number of accidents in 2020 across all severity levels.
# >    - This spike could be attributed to various factors, including changes in traffic patterns and behaviors due to the COVID-19 pandemic.
# >
# > 5. **Highest Number of Accidents in 2022**:
# >    - The year 2022 recorded the highest number of accidents, particularly for Severity 2.
# >    - This trend suggests an overall increase in accident occurrences, highlighting the need for enhanced road safety measures.
# >
# > 6. **Severity 4 Accidents**:
# >    - Although Severity 4 accidents are the least common, their numbers have shown a slight increase in recent years.
# >    - This increase emphasizes the importance of addressing factors contributing to the most severe accidents to improve overall road safety.

# %%
plt.figure(figsize=(12,5))
perc_month_barplot = sns.barplot(df['Start_Time'].dt.month.value_counts().sort_index()*100/df.shape[0], color='red')
for i in perc_month_barplot.containers:
    perc_month_barplot.bar_label(i, fmt='%.2f%%')
plt.xlabel('Month of the year')
plt.ylabel('Percentage of Accidents')    
plt.title('Percentage of Accidents by Month')
# Out:
# Text(0.5, 1.0, 'Percentage of Accidents by Month')

# %% [markdown]
# >### Insights on Percentage of Accidents by Month
# >
# >1. **Consistent Distribution**:
# >    - The percentage of accidents is relatively evenly distributed across all months.
# >    - There are no extreme peaks or troughs, indicating that accidents occur consistently throughout the year.
# >
# >2. **Winter Months**:
# >    - There is a slight increase in the percentage of accidents during the winter months (November, December, January).
# >    - This could be attributed to adverse weather conditions such as snow, ice, and reduced visibility.
# >
# >3. **Summer Months**:
# >    - The summer months (June, July, August) also show a higher percentage of accidents.
# >    - Increased travel during summer vacations and holidays may contribute to this trend.
# >
# >4. **Spring and Fall**:
# >    - The percentage of accidents during the spring (March, April, May) and fall (September, October) months is relatively stable.
# >    - These periods do not show significant deviations from the average monthly accident percentage.
# >
# >5. **Holiday Impact**:
# >    - The end-of-year holiday season (December) shows a noticeable increase in accidents.
# >    - Increased travel and potentially hazardous weather conditions during this period may lead to a higher number of accidents.
# >
# >6. **Monthly Trends**:
# >    - The data suggests that while accidents occur throughout the year, certain months have slightly higher percentages, likely due to seasonal and holiday-related factors.

# %%
df_plot = df[['Start_Time', 'Severity']].copy()
df_plot['Month'] = df_plot['Start_Time'].dt.month

plt.figure(figsize=(12,5))
sns.histplot(data=df_plot, x='Month', bins=12, hue='Severity', multiple='stack', palette='plasma')
plt.title('Distribution of Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# >### Insights
# >1. **Severity 2 Accidents**:
# >    - Severity 2 accidents are consistently the most common across all months.
# >    - There is a noticeable increase in Severity 2 accidents during the winter months (November, December, January).
# >
# >2. **Severity 3 Accidents**:
# >    - Severity 3 accidents show a relatively stable distribution throughout the year.
# >    - There is a slight increase in Severity 3 accidents during the summer months (June, July, August).
# >
# >3. **Severity 1 and 4 Accidents**:
# >    - Severity 1 accidents have a relatively even distribution across all months.
# >    - Severity 4 accidents, although the least common, show a slight increase during the winter months.
# >
# >4. **Seasonal Variations**:
# >    - The winter months (November, December, January) have a higher number of accidents across all severity levels.
# >    - This trend suggests that adverse weather conditions during winter may contribute to an increase in accident occurrences.
# >
# >5. **Monthly Trends**:
# >    - The number of accidents tends to be higher at the beginning and end of the year.
# >    - There is a noticeable dip in the number of accidents during the spring months (March, April, May).

# %%
plt.figure(figsize=(12,5))
perc_days_barplot = sns.barplot(df['Start_Time'].dt.dayofweek.value_counts().sort_index()*100/df.shape[0], color='red')
for i in perc_days_barplot.containers:
    perc_days_barplot.bar_label(i, fmt='%.2f%%')
plt.xlabel('Day of the week')
plt.ylabel('Percentage of Accidents')    
plt.title('Percentage of Accidents by Day of the Week')
# Out:
# Text(0.5, 1.0, 'Percentage of Accidents by Day of the Week')

# %% [markdown]
# >### Insights on Percentage of Accidents by Day of the Week
# >
# >1. **Weekday Dominance**:
# >    - The majority of accidents occur on weekdays, with a noticeable drop during weekends.
# >    - This trend suggests that higher traffic volumes and commuting activities during weekdays contribute to a higher number of accidents.
# >
# >2. **Friday Peak**:
# >    - Among the weekdays, Friday has the highest percentage of accidents.
# >    - This could be due to increased travel and social activities as people prepare for the weekend.
# >
# >3. **Monday and Tuesday**:
# >    - Monday and Tuesday also show relatively high percentages of accidents, likely due to the start of the workweek and increased commuting.
# >
# >4. **Weekend Drop**:
# >    - There is a significant drop in the percentage of accidents on Saturday and Sunday.
# >    - Lower traffic volumes and fewer commuting activities during weekends likely contribute to the reduced accident count.
# >
# >5. **Consistent Patterns**:
# >    - The distribution of accidents by day of the week shows consistent patterns, with clear peaks on weekdays and dips on weekends.
# >    - These patterns highlight the impact of traffic volume and commuting behavior on accident occurrences.

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['Start_Time'].dt.hour, bins=24, color='red')
plt.title('Distribution of Accidents by Hour')
plt.xlabel('Hour')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# >### Insights on Distribution of Accidents by Hour
# >
# >1. **Morning and Evening Peaks**:
# >    - There are two noticeable peaks in the number of accidents: one in the morning (6 AM to 9 AM) and another in the evening (3 PM to 6 PM).
# >    - These peaks correspond to the rush hours when people are commuting to and from work, leading to increased traffic and a higher likelihood of accidents.
# >
# >2. **Midday Dip**:
# >    - There is a dip in the number of accidents during the midday hours, roughly between 10 AM and 2 PM.
# >    - This period typically has lower traffic volumes, which may contribute to the reduced number of accidents.
# >
# >3. **Late Night and Early Morning**:
# >    - The number of accidents decreases significantly during the late night and early morning hours, from 10 PM to 5 AM.
# >    - Lower traffic volumes and fewer vehicles on the road during these hours likely contribute to the reduced accident count.
# >
# >4. **Consistent Patterns**:
# >    - The distribution of accidents by hour shows consistent patterns, with clear peaks during rush hours and dips during off-peak hours.
# >    - These patterns highlight the impact of traffic volume and commuting behavior on accident occurrences.
# >
# >### Detailed Analysis by Hour on Weekdays and Weekends Below

# %%
plt.figure(figsize=(12,5))
weekdays = df[(df['Start_Time'].dt.dayofweek==0) | (df['Start_Time'].dt.dayofweek==1) | (df['Start_Time'].dt.dayofweek==2) | (df['Start_Time'].dt.dayofweek==3) | (df['Start_Time'].dt.dayofweek==4)]
sns.histplot(weekdays["Start_Time"].dt.hour, bins=24, color='red', label='Weekend', alpha=0.5, stat='density')
plt.title('Distribution of Accidents by Hour on Weekdays')
plt.xlabel('Hour')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# >### Insights on Distribution of Accidents by Hour on Weekdays
# >
# >1. **Morning Peak**:
# >    - There is a noticeable peak in the number of accidents during the morning rush hours, specifically between 6 AM and 9 AM.
# >    - This trend suggests that increased traffic volume during the morning commute contributes to a higher number of accidents.
# >
# >2. **Evening Peak**:
# >    - Another significant peak occurs during the evening rush hours, from 3 PM to 6 PM.
# >    - Similar to the morning peak, the evening peak is likely due to increased traffic as people return home from work.
# >
# >3. **Midday Dip**:
# >    - There is a dip in the number of accidents during the midday hours, roughly between 10 AM and 2 PM.
# >    - This period typically has lower traffic volumes, which may contribute to the reduced number of accidents.
# >
# >4. **Late Night and Early Morning**:
# >    - The number of accidents decreases significantly during the late night and early morning hours, from 10 PM to 5 AM.
# >    - Lower traffic volumes and fewer vehicles on the road during these hours likely contribute to the reduced accident count.
# >
# >5. **Consistent Patterns**:
# >    - The distribution of accidents by hour on weekdays shows consistent patterns, with clear peaks during rush hours and dips during off-peak hours.
# >    - These patterns highlight the impact of traffic volume and commuting behavior on accident occurrences.

# %%
plt.figure(figsize=(12,5))
weekend = df[(df['Start_Time'].dt.dayofweek==5) | (df['Start_Time'].dt.dayofweek==6)]
sns.histplot(weekend["Start_Time"].dt.hour, bins=24, color='red', label='Weekend', alpha=0.5, stat='density')
plt.title('Distribution of Accidents by Hour on Weekends')
plt.xlabel('Hour')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# >### Insights on Distribution of Accidents by Hour on Weekends
# >
# >1. **Midday Peak**:
# >    - There is a noticeable peak in the number of accidents during the midday hours, specifically between 10 AM and 2 PM.
# >    - This trend suggests that increased activity and travel during these hours contribute to a higher number of accidents.
# >
# >2. **Evening Peak**:
# >    - Another significant peak occurs during the evening hours, from 4 PM to 7 PM.
# >    - This period likely corresponds to leisure activities and social events, leading to increased traffic and accident occurrences.
# >
# >3. **Late Night and Early Morning**:
# >    - The number of accidents decreases significantly during the late night and early morning hours, from 10 PM to 6 AM.
# >    - Lower traffic volumes and fewer vehicles on the road during these hours likely contribute to the reduced accident count.
# >
# >4. **Consistent Patterns**:
# >    - The distribution of accidents by hour on weekends shows consistent patterns, with clear peaks during midday and evening hours.
# >    - These patterns highlight the impact of leisure activities and social behavior on accident occurrences.

# %% [markdown]
# ### Weather Condition

# %%
fig = plt.figure(figsize = (11,4))
sns.barplot(df['Weather_Condition'].value_counts()[:15], color='red')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Weather Condition')
plt.title('Top 15 Weather Conditions by Count')
plt.show()

# %% [markdown]
# >### Insights on Top 15 Weather Conditions by Count
# >
# >1. **Fair Weather**:
# >    - Fair weather conditions have the highest count of accidents, indicating that a significant number of accidents occur under clear weather conditions.
# >
# >2. **Mostly Cloudy and Cloudy**:
# >    - Mostly cloudy and cloudy conditions follow fair weather in terms of accident count.
# >    - These conditions may contribute to reduced visibility and increased accident risk.
# >
# >3. **Overcast**:
# >    - Overcast conditions also have a high count of accidents, suggesting that completely cloudy skies may impact driving conditions.
# >
# >4. **Light Rain**:
# >    - Light rain is a common weather condition during accidents, highlighting the potential hazards of wet roads.
# >
# >5. **Scattered Clouds and Partly Cloudy**:
# >    - Scattered clouds and partly cloudy conditions have a moderate count of accidents.
# >    - These conditions may still pose visibility challenges for drivers.
# >
# >6. **Heavy Rain and Rain**:
# >    - Heavy rain and rain conditions have a lower count of accidents compared to lighter rain.
# >    - However, these conditions are still significant contributors to accident occurrences.
# >
# >7. **Fog and Haze**:
# >    - Fog and haze conditions have a noticeable count of accidents, emphasizing the dangers of reduced visibility.
# >
# >8. **Snow and Light Snow**:
# >    - Snow and light snow conditions are less common but still present in the top 15 weather conditions.
# >    - These conditions can lead to slippery roads and increased accident risk.
# >
# >9. **Thunderstorms**:
# >    - Thunderstorms have a lower count of accidents but are still notable.
# >    - The combination of heavy rain, lightning, and strong winds can create hazardous driving conditions.
# >
# >10. **General Observations**:
# >    - The majority of accidents occur under fair, cloudy, and light rain conditions.
# >    - Adverse weather conditions such as heavy rain, fog, and snow also contribute to accident occurrences, though to a lesser extent.
# >    - Understanding the impact of different weather conditions on accident risk can help in developing targeted road safety measures.

# %%
weather_cond=df["Temperature(F)"].value_counts()
plt.figure(figsize=(12,5))
plt.title(" Accident cases reported for different Temperatures",size=17,color="grey")
plt.xlabel('No. of accidents')
plt.ylabel('Temperature(F)')
sns.scatterplot(y=weather_cond.index, x=weather_cond)
# Out:
# <Axes: title={'center': ' Accident cases reported for different Temperatures'}, xlabel='No. of accidents', ylabel='Temperature(F)'>

# %% [markdown]
# > ### Insights on Accident Cases Reported for Different Temperatures
# >
# > 1. **Moderate Temperature Range:** Most accidents occur at moderate temperatures (around 70°F to 80°F), suggesting that these conditions are the most common during typical driving hours.
# >
# > 2. **Fewer Extremes:** There is a notable drop in accident counts at very low and very high temperatures, which might be due to reduced traffic volumes or more cautious driving in extreme weather.
# >
# > 3. **Weather Condition Influence:** Although fair weather is prevalent in many accidents, the temperature distribution points toward underlying factors—such as driver behavior and road conditions—that also significantly contribute to accident occurrences.
# >
# > 4. **Need for Deeper Analysis:** Further investigation could reveal if temperature variations affect not only the number but also the severity of accidents, providing insights for targeted safety measures.

# %%
humidity_effect=df["Humidity(%)"].value_counts()
plt.figure(figsize=(12,5))
plt.title(" Accident cases reported for different humidity ",size=17,color="grey")
plt.xlabel('No. of accidents')
plt.ylabel('Humidity(%) ')
sns.scatterplot(y=humidity_effect.index, x=humidity_effect)
# Out:
# <Axes: title={'center': ' Accident cases reported for different humidity '}, xlabel='No. of accidents', ylabel='Humidity(%) '>

# %% [markdown]
# > ### Insights on Accidents for Different Humidity Levels
# >
# > - The accident count distribution indicates that the majority of incidents occur under high humidity conditions (e.g., around 93% to 100% humidity show the largest counts).
# > - High humidity environments may coincide with adverse weather conditions, which can reduce visibility and road traction, potentially increasing accident risk.
# > - In contrast, lower humidity levels register much fewer accidents, suggesting that drier conditions are generally associated with safer driving conditions.
# > - Further investigation into the interplay between high humidity and other weather variables (such as precipitation or fog) could help in developing targeted road safety measures.

# %%
windspeed_effect=df["Wind_Speed(mph)"].value_counts()
plt.figure(figsize=(9,4))
plt.title(" Accident cases reported for different Windspeed ",size=17,color="grey")
plt.xlabel('No. of accidents')
plt.ylabel('Wind_Speed(mph)')
sns.scatterplot(y=windspeed_effect.index, x=windspeed_effect)
plt.show()

# %% [markdown]
# > ### Insights for Accident cases reported for different Windspeed
# > - Most accidents occur at lower wind speeds, particularly around 0 mph, indicating calm conditions.
# > - There is a significant drop in accident counts as wind speed increases, suggesting that higher wind speeds are less common during accident events.
# > - The distribution highlights that typical, low-wind conditions are more frequently associated with accidents than high-wind scenarios.

# %%
pressure_effect=df["Pressure(in)"].value_counts()
plt.figure(figsize=(9,4))
plt.title(" Accident cases reported for different pressures ",size=17,color="grey")
plt.xlabel('No. of accidents')
plt.ylabel('Pressure(in)')
sns.scatterplot(y=pressure_effect.index, x=pressure_effect)
plt.show()

# %% [markdown]
# > ### Insights for Accident cases reported for different pressures
# > - Most accidents occur at lower atmospheric pressures, particularly around 29.9 in to 30.0 in.
# > - There is a significant drop in accident counts as pressure deviates from this range, suggesting that typical atmospheric conditions are more frequently associated with accidents than extreme pressure scenarios.
# > - The distribution highlights that accidents are more common under normal pressure conditions.

# %%
# Plotting the distribution of accidents based on the distance affected
plt.figure(figsize=(12, 6))
sns.histplot(df['Distance(mi)'], bins=50, color='red', log_scale=True, kde=True)
plt.title('Distribution of Accidents by Distance Affected')
plt.xlabel('Distance (mi)')
plt.ylabel('Count')
plt.show()
# Out:
# d:\python\venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %% [markdown]
# > ### Insights on Distribution of Accidents by Distance
# >
# > 1. **Short Distance Dominance**:
# >    - Most accidents affect very short distances, with many affecting just 0.01 miles.
# >    - Indicates that most accidents are minor with limited road impact.
# >
# > 2. **Exponential Decrease**:
# >    - Number of accidents decreases exponentially as the affected distance increases.
# >    - Suggests that severe accidents impacting longer distances are less common.
# >
# > 3. **Log-Scale Distribution**:
# >    - Log-scale highlights the steep drop-off in accident counts with increasing distance.
# >    - Typical pattern in accident data where minor incidents are more frequent.
# >
# > 4. **Rare Long-Distance Accidents**:
# >    - Accidents affecting distances greater than a few miles are rare.
# >    - Likely correspond to severe accidents with significant road closures.
# >
# > 5. **General Observations**:
# >    - Understanding distance distribution helps in resource allocation and emergency response planning.
# >    - Data suggests most accidents are minor, but severe ones need substantial attention.

# %% [markdown]
# # 🚦 US Accidents (2016 - 2023) - Exploratory Data Analysis (EDA)
#
# ## 📌 Introduction
# This report presents a **detailed exploratory data analysis (EDA)** on the **US Accidents Dataset (2016-2023)**. The dataset contains approximately **7.7 million accident records** across **49 US states**, with attributes such as **time, location, weather conditions, and accident severity**.
#
# The primary objectives of this analysis include:
# - Understanding **geographical distribution** of accidents.
# - Identifying **high-risk states and cities**.
# - Examining **time-based accident trends**.
# - Analyzing **weather conditions affecting accidents**.
# - Assessing **accident severity levels**.
#
# ---
#
# ## 📊 1. Data Overview and Preprocessing
# ### ✅ Data Summary
# - **7,743,387 total records**.
# - **49 states covered** (excluding Alaska and Hawaii).
# - Features include **latitude, longitude, temperature, humidity, wind speed, precipitation, sunrise/sunset times, etc.**.
# - **Missing values** in `Precipitation(in)`, `Wind_Chill(F)`, and `Wind_Speed(mph)`, requiring handling before modeling.
# - **No duplicate records** found in the dataset.
#
# ---
#
# ## 🌎 2. Geographical Distribution of Accidents
# ### 📍 **Which states have the highest number of accidents?**
# | State      | Accident Count | % of Total |
# |------------|---------------|------------|
# | **California (CA)**  | **1,744,070** | **22.5%** |
# | **Florida (FL)**      | **880,869**  | **11.4%** |
# | **Texas (TX)**        | **583,648**  | **7.5%** |
# | **North Carolina (NC)** | **413,647**  | **5.3%** |
#
# - **California, Florida, and Texas together account for ~42% of total accidents.**
# - **West Coast and Southeastern states** have a significantly higher accident rate.
#
# ### 🏙️ **Which cities experience the most accidents?**
# | City         | Accident Count |
# |-------------|---------------|
# | **Miami, FL**    | **103,000+** |
# | **Houston, TX**  | **97,500+** |
# | **Los Angeles, CA** | **95,000+** |
# | **Charlotte, NC** | **80,000+** |
#
# - **Miami leads in accident frequency**, possibly due to **high urban density and tourism traffic**.
# - **Texas and California have multiple high-accident cities**.
#
# ### 🛣️ **Most Dangerous Roads & Highways**
# - **Interstates I-95, I-5, I-10, and I-75** are hotspots for accidents.
# - **Urban highways** have higher accident rates due to traffic congestion.
#
# ---
#
# ## ⚠️ 3. Severity of Accidents
# ### 🔥 **What percentage of accidents are severe?**
# | Severity Level | Description | Percentage |
# |---------------|------------|------------|
# | **Severity 1** | **Minor accident, no blockage** | **3%** |
# | **Severity 2** | **Moderate impact, road remains open** | **80%** |
# | **Severity 3** | **Major accident, partial road closure** | **16%** |
# | **Severity 4** | **Severe accident, full road closure** | **1%** |
#
# - **Most accidents (~80%) are of Severity 2, indicating moderate impact**.
# - **Severity 4 accidents (most severe) are rare but highly disruptive**.
# - **Atlanta, GA** has the highest number of **Severity 4 accidents**.
#
# ---
#
# ## ⏳ 4. Temporal Analysis: When Do Accidents Happen?
# ### 📅 **Accidents by Year**
# - **Steady increase in accidents from 2016 to 2022**.
# - **2020 saw a significant dip**, likely due to COVID-19 lockdowns.
#
# ### 📆 **Accidents by Day of the Week**
# | Day       | % of Accidents |
# |-----------|---------------|
# | **Monday**  | **13.9%**  |
# | **Tuesday** | **14.7%**  |
# | **Wednesday** | **15.2%**  |
# | **Thursday** | **15.4%**  |
# | **Friday**   | **16.1%**  |
# | **Saturday** | **12.5%**  |
# | **Sunday**   | **11.2%**  |
#
# - **Fridays** have the highest accident rates, likely due to **increased travel before weekends**.
# - **Weekends have fewer accidents**, possibly due to **less commuter traffic**.
#
# ### ⏰ **Accidents by Hour of the Day**
# - **Morning peak (6 AM - 9 AM):** Accidents increase due to **rush hour traffic**.
# - **Evening peak (3 PM - 6 PM):** Highest accident occurrence due to **return commute**.
# - **Late night (12 AM - 4 AM):** Fewer accidents but higher severity (due to speeding, fatigue, or DUI).
#
# ---
#
# ## 🌦 5. Weather and Environmental Factors
# ### ☁️ **Weather Conditions During Accidents**
# | Weather Condition | % of Accidents |
# |------------------|---------------|
# | **Clear / Fair**  | **68%** |
# | **Cloudy / Overcast** | **18%** |
# | **Rainy / Foggy** | **10%** |
# | **Snowy / Stormy** | **4%** |
#
# - **Surprisingly, most accidents occur in clear weather** (likely due to high traffic volume).
# - **Adverse weather (rain, fog, snow) contributes to higher severity accidents**.
#
# ### 🌡️ **Temperature and Accidents**
# - **Most accidents occur at moderate temperatures (70°F - 80°F)**.
# - **Extremely cold or hot temperatures lead to fewer accidents**.
#
# ---
#
# ## 📏 6. Distance Analysis: How Much Road Is Affected?
# | Distance Affected | % of Accidents |
# |------------------|---------------|
# | **0.01 miles**  | **65%** |
# | **0.1 - 0.5 miles** | **25%** |
# | **1+ miles** | **10%** |
#
# - **Most accidents affect a very short distance (~0.01 miles), suggesting minor impact**.
# - **Severe accidents covering longer distances (~1 mile) are rare**.
#
# ---
#
# ## 🔑 7. Key Insights & Takeaways
# 1. **California (22.5%), Florida (11.4%), and Texas (7.5%) account for nearly half of all accidents**.
# 2. **Severity 2 accidents dominate (80%)**, while **Severity 4 accidents (most severe) are rare**.
# 3. **Miami, Houston, and Los Angeles are the most accident-prone cities**.
# 4. **Fridays and rush hours (6-9 AM, 3-6 PM) have the highest accident rates**.
# 5. **Winter months (November - January) and holiday seasons see a surge in accidents**.
# 6. **Fair weather conditions see the most accidents, but severe weather leads to more serious crashes**.
# 7. **Short-distance accidents (~0.01 miles) make up the majority of cases**.
#
# ---
#
# ## 🏁 Conclusion: What Can Be Done?
# This analysis highlights **critical accident patterns** in the US. Some **potential actions** include:
# - **Traffic management policies in high-accident states (CA, FL, TX)**.
# - **Stricter regulations for peak hours and high-risk roads (I-95, I-5, I-10)**.
# - **Improved road infrastructure and early warnings in severe weather conditions**.
# - **Public awareness campaigns on weekend and rush-hour safety**.
#
# This EDA provides valuable insights for **traffic authorities, urban planners, and policymakers** to design **safer roads and better transportation systems**.
#
# ---
